# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

haber =pd.read_csv("D:\\!!data\\haberman.csv")

# %%
print(haber.size)
# Out:
# 1224

# %%
print(haber.columns)
# Out:
# Index(['patient_age', 'operation_year', 'nodes_detected', 'survival_status'], dtype='object')

# %%
haber.plot(kind="scatter", x="patient_age", y="nodes_detected")
plt.grid()
plt.show()

# %%
sns.FacetGrid(haber, hue="nodes_detected", height=8) \
    .map(sns.histplot, "patient_age")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
